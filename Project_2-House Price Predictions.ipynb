# %% [markdown]
# https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
import io
# %cd "C:\Users\91866\Desktop\github_dataset\House Price Predictions"
# Out:
# C:\Users\91866\Desktop\github_dataset\House Price Predictions

# %%
housetrain=pd.read_csv("train.csv")

# %%
housetest=pd.read_csv("test.csv")

# %%
print(housetrain.shape)
print(housetest.shape)
# Out:
# (1460, 81)
# (1459, 80)

# %%
housetrain.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
housetrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
housetest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
housetrain.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
# Adding dependant variable temporarily to test data.
housetest['SalePrice']='test'

# %%
# Conacatening train and test data for preprocessing.row wies concatenation so axis=0.
combinedf=pd.concat([housetrain,housetest],axis=0)

# %%
combinedf.shape
# Out:
# (2919, 81)

# %%
combinedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 0 to 1458
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2919 non-null   int64
#  1   MSSubClass     2919 non-null   int64
#  2   MSZoning       2915 non-null   object
#  3   LotFrontage    2433 non-null   float64
#  4   LotArea        2919 non-null   int64
#  5   Street         2919 non-null   object
#  6   Alley          198 non-null    object
#  7   LotShape       2919 non-null   object
#  8   LandContour    2919 non-null   object
#  9   Utilities      2917 non-null   object
#  10  LotConfig      2919 non-null   object
#  11  LandSlope      2919 non-null   object
#  12  Neighborhood   2919 non-null   object
#  13  Condition1     2919 non-null   object
#  14  Condition2     2919 non-null   object
#  15  BldgType       2919 non-null   object
#  16  HouseStyle     2919 non-null   object
# ...

# %% [markdown]
# Exploratory Data Analysis

# %%
# if large/complete no of column missing value .
pd.set_option("display.max_rows",82)
combinedf.isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC           2909
# MiscFeature      2814
# Alley            2721
# Fence            2348
# FireplaceQu      1420
# LotFrontage       486
# GarageFinish      159
# GarageQual        159
# GarageCond        159
# GarageYrBlt       159
# GarageType        157
# BsmtExposure       82
# BsmtCond           82
# BsmtQual           81
# BsmtFinType2       80
# BsmtFinType1       79
# MasVnrType         24
# MasVnrArea         23
# MSZoning            4
# Functional          2
# Utilities           2
# BsmtHalfBath        2
# BsmtFullBath        2
# GarageArea          1
# BsmtFinSF1          1
# SaleType            1
# GarageCars          1
# BsmtUnfSF           1
# Electrical          1
# Exterior2nd         1
# Exterior1st         1
# KitchenQual         1
# TotalBsmtSF         1
# BsmtFinSF2          1
# TotRmsAbvGrd        0
# Fireplaces          0
# Id                  0
# BedroomAbvGr        0
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# ...

# %%
sns.heatmap(combinedf.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot: >

# %%
# Split data into objectcols and numericals
objectcols=combinedf.select_dtypes(include=['object'])
numariccols=combinedf.select_dtypes(include=np.number)

# %%
print(objectcols.shape)
print(numariccols.shape)
# Out:
# (2919, 44)
# (2919, 37)

# %%
objectcols.isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC           2909
# MiscFeature      2814
# Alley            2721
# Fence            2348
# FireplaceQu      1420
# GarageCond        159
# GarageQual        159
# GarageFinish      159
# GarageType        157
# BsmtCond           82
# BsmtExposure       82
# BsmtQual           81
# BsmtFinType2       80
# BsmtFinType1       79
# MasVnrType         24
# MSZoning            4
# Utilities           2
# Functional          2
# Exterior2nd         1
# Electrical          1
# SaleType            1
# Exterior1st         1
# KitchenQual         1
# RoofStyle           0
# Neighborhood        0
# SaleCondition       0
# ExterQual           0
# LotShape            0
# LandContour         0
# ExterCond           0
# PavedDrive          0
# LotConfig           0
# LandSlope           0
# Condition1          0
# HouseStyle          0
# Condition2          0
# Foundation          0
# RoofMatl            0
# Street              0
# CentralAir          0
# HeatingQC           0
# ...

# %%
notavailablecols=['PoolQC','MiscFeature','Alley','Fence','FireplaceQu']

# %%
for col in notavailablecols:
    objectcols[col]=objectcols[col].fillna("NotAvailable")

# %%
garage_list=[col for col in objectcols if col.startswith('Gar')]
garage_list
# Out:
# ['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']

# %%
for col in garage_list:
    freq=objectcols[col].value_counts(dropna=False)
    print(freq)
# Out:
# Attchd     1723
# Detchd      779
# BuiltIn     186
# NaN         157
# Basment      36
# 2Types       23
# CarPort      15
# Name: GarageType, dtype: int64
# Unf    1230
# RFn     811
# Fin     719
# NaN     159
# Name: GarageFinish, dtype: int64
# TA     2604
# NaN     159
# Fa      124
# Gd       24
# Po        5
# Ex        3
# Name: GarageQual, dtype: int64
# TA     2654
# NaN     159
# Fa       74
# Gd       15
# Po       14
# Ex        3
# Name: GarageCond, dtype: int64

# %%
Bsmt_list=[col for col in objectcols if col.startswith('Bsmt')]
Bsmt_list
# Out:
# ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']

# %%
for col in Bsmt_list:
    freq=objectcols[col].value_counts(dropna=False)
    print(freq)
# Out:
# TA     1283
# Gd     1209
# Ex      258
# Fa       88
# NaN      81
# Name: BsmtQual, dtype: int64
# TA     2606
# Gd      122
# Fa      104
# NaN      82
# Po        5
# Name: BsmtCond, dtype: int64
# No     1904
# Av      418
# Gd      276
# Mn      239
# NaN      82
# Name: BsmtExposure, dtype: int64
# Unf    851
# GLQ    849
# ALQ    429
# Rec    288
# BLQ    269
# LwQ    154
# NaN     79
# Name: BsmtFinType1, dtype: int64
# Unf    2493
# Rec     105
# LwQ      87
# NaN      80
# BLQ      68
# ALQ      52
# GLQ      34
# Name: BsmtFinType2, dtype: int64

# %%
# Most frequent imputation for all remaing variable in object call.
for col in objectcols.columns:
    objectcols[col]=objectcols[col].fillna(objectcols[col].value_counts().idxmax())

# %%
numariccols.isnull().sum().sort_values(ascending=False)
# within numaric variable ,there might be categorical variable
#Categorical variable must be seperated from numaric variable
# categorical variable like year,rating,dummyencoded(0/1),etc
# Out:
# LotFrontage      486
# GarageYrBlt      159
# MasVnrArea        23
# BsmtHalfBath       2
# BsmtFullBath       2
# BsmtFinSF2         1
# GarageCars         1
# GarageArea         1
# TotalBsmtSF        1
# BsmtUnfSF          1
# BsmtFinSF1         1
# KitchenAbvGr       0
# 3SsnPorch          0
# EnclosedPorch      0
# OpenPorchSF        0
# WoodDeckSF         0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# Fireplaces         0
# TotRmsAbvGrd       0
# Id                 0
# BedroomAbvGr       0
# HalfBath           0
# FullBath           0
# MSSubClass         0
# GrLivArea          0
# LowQualFinSF       0
# 2ndFlrSF           0
# 1stFlrSF           0
# YearRemodAdd       0
# YearBuilt          0
# OverallCond        0
# OverallQual        0
# LotArea            0
# YrSold             0
# dtype: int64

# %%
numariccols.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold'],
#       dtype='object')

# %%
categorycols=numariccols[['OverallQual',
       'OverallCond', 'YearBuilt', 'YearRemodAdd','GarageYrBlt','MoSold', 'YrSold']]

# %%
numariccols=numariccols.drop(['OverallQual',
       'OverallCond', 'YearBuilt', 'YearRemodAdd','GarageYrBlt','MoSold', 'YrSold'],axis=1)

# %%
print(categorycols.shape)
print(numariccols.shape)
# Out:
# (2919, 7)
# (2919, 30)

# %%
categorycols.isnull().sum().sort_values(ascending=False)
# Out:
# GarageYrBlt     159
# OverallQual       0
# OverallCond       0
# YearBuilt         0
# YearRemodAdd      0
# MoSold            0
# YrSold            0
# dtype: int64

# %%
categorycols.GarageYrBlt=categorycols.GarageYrBlt.fillna(categorycols.GarageYrBlt.value_counts().idxmax())

# %%
# Median imputation for Numaric cols

for col in numariccols.columns:
    numariccols[col]=numariccols[col].fillna(numariccols[col].median())

# %% [markdown]
# Encoding and Model Building

# %%
# Lable Encoding or Dummy Encoding objectcols and categorical
# we cant have column greture tha  rows so not going with dummy encoder

from sklearn.preprocessing import LabelEncoder

# %%
#Any Mix datatype bydefault goes into object
#lable will not workl for mix datatype
numariccols['SalePrice']=objectcols.SalePrice

# %%
objectcols=objectcols.drop('SalePrice',axis=1)

# %%
le=LabelEncoder()

# %%
objectcols_encode=objectcols.apply(le.fit_transform)

# %%
categorycols_encode=categorycols.apply(le.fit_transform)

# %%
objectcols_encode.head()
# Out:
#    MSZoning  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 0         3       1      1         3            3          0          4
# 1         3       1      1         3            3          0          2
# 2         3       1      1         0            3          0          4
# 3         3       1      1         0            3          0          0
# 4         3       1      1         0            3          0          2
#
#    LandSlope  Neighborhood  Condition1  ...  GarageType  GarageFinish  \
# 0          0             5           2  ...           1             1
# 1          0            24           1  ...           1             1
# 2          0             5           2  ...           1             1
# 3          0             6           2  ...           5             2
# 4          0            15           2  ...           1             1
#
#    GarageQual  GarageCond  PavedDrive  PoolQC  Fence  MiscFeature  SaleType  \
# ...

# %%
numariccols.drop('SalePrice',axis=1).corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  MasVnrArea  \
# Id             1.000000    0.008931    -0.024710 -0.040746   -0.026737
# MSSubClass     0.008931    1.000000    -0.389469 -0.201730    0.006309
# LotFrontage   -0.024710   -0.389469     1.000000  0.361426    0.200474
# LotArea       -0.040746   -0.201730     0.361426  1.000000    0.124728
# MasVnrArea    -0.026737    0.006309     0.200474  0.124728    1.000000
# BsmtFinSF1    -0.016988   -0.064254     0.201697  0.194050    0.301427
# BsmtFinSF2     0.018170   -0.072431     0.040330  0.084107   -0.014580
# BsmtUnfSF     -0.014509   -0.125913     0.106921  0.021400    0.087991
# TotalBsmtSF   -0.024960   -0.219893     0.330765  0.254150    0.393662
# 1stFlrSF      -0.008678   -0.248641     0.423217  0.332460    0.392367
# 2ndFlrSF      -0.022252    0.309309     0.023249  0.031515    0.119377
# LowQualFinSF  -0.037816    0.026482     0.005142  0.000554   -0.057380
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize=(30,15))
sns.heatmap(numariccols.drop('SalePrice',axis=1).corr(),annot=True)
plt.show()

# %%
numariccols.head()
# scling must eb done because data in mulitple datatypes
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# 0   1          60         65.0     8450       196.0       706.0         0.0
# 1   2          20         80.0     9600         0.0       978.0         0.0
# 2   3          60         68.0    11250       162.0       486.0         0.0
# 3   4          70         60.0     9550         0.0       216.0         0.0
# 4   5          60         84.0    14260       350.0       655.0         0.0
#
#    BsmtUnfSF  TotalBsmtSF  1stFlrSF  ...  GarageCars  GarageArea  WoodDeckSF  \
# 0      150.0        856.0       856  ...         2.0       548.0           0
# 1      284.0       1262.0      1262  ...         2.0       460.0         298
# 2      434.0        920.0       920  ...         2.0       608.0           0
# 3      540.0        756.0       961  ...         3.0       642.0           0
# 4      490.0       1145.0      1145  ...         3.0       836.0         192
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
numariccols_scaled=scaler.fit_transform(numariccols.drop('SalePrice',axis=1))

# %%
numariccols.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'MasVnrArea',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'SalePrice'],
#       dtype='object')

# %%
numariccols_scaled=pd.DataFrame(numariccols_scaled,columns=['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'MasVnrArea',
       'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
       '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
       'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
       'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal'])

# SalePrice is not putting here
# or we can put columns[0:30] insted of putting all names

# %%
 # First we have to reset index for all cols
numariccols_scaled=numariccols_scaled.reset_index()

# %%
objectcols_encode=objectcols_encode.reset_index()

# %%
categorycols_encode=categorycols_encode.reset_index()

# %%
combinedf_clean=pd.concat([numariccols_scaled,objectcols_encode,categorycols_encode],axis=1)

# %%
numariccols=numariccols.reset_index()

# %%
combinedf_clean['SalePrice']=numariccols.SalePrice

# %%
housetrain_df=combinedf_clean[combinedf_clean.SalePrice!='test']
housetest_df=combinedf_clean[combinedf_clean.SalePrice=='test']

# %%
housetest_df=housetest_df.drop('SalePrice',axis=1)

# %%
# Split data in y and X
y=housetrain_df.SalePrice
X=housetrain_df.drop(['Id','SalePrice','index'],axis=1)

# %%
housetest_df=housetest_df.drop(['Id','index'],axis=1)

# %%
y=y.astype('int64')

# %%
# Histogram,Boxplot and Density Curve for y
y.plot(kind='hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
np.log(y).plot(kind='box',vert=False)
# Out:
# <AxesSubplot: >

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
regmodel=reg.fit(X,y)

# %%
regmodel.score(X,y)
# R Sqaure value
#t should be between 0.60-0.95 
#  if not in between  the model will be underfitting or overfitting
# Out:
# 0.8544531061204118

# %%
regmodel.intercept_
# Out:
# 364375.19908902864

# %%
# Predict
regpredict=regmodel.predict(X)
regpredict
# Out:
# array([216899.05502804, 199808.50644654, 218453.50205413, ...,
#        243066.81422413, 149232.12382877, 161479.81065575])

# %%
# Residual
regresid=y-regpredict
regresid
# Out:
# 0       -8399.055028
# 1      -18308.506447
# 2        5046.497946
# 3      -33673.066728
# 4      -35841.575236
#             ...
# 1455     5170.125118
# 1456   -10990.075861
# 1457    23433.185776
# 1458    -7107.123829
# 1459   -13979.810656
# Name: SalePrice, Length: 1460, dtype: float64

# %%
np.sqrt(np.mean(regresid**2))
# Out:
# 30297.41719937248
